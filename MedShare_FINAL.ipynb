# %% [markdown]
# # 🏥 MedShare: Federated Learning for Survival Analysis
#
# > **Mode**: Full Scientific Run (Complete Dataset)
# >
# > **Kernel**: Ensure the top right shows **Google Colab**
# >
# > **Runtime**: Python 3 with GPU (optional, works on CPU too)
#
# ---
#
# ## 📋 Execution Flow
#
# 1. **Setup** - Mount Drive, Install Dependencies, Deploy Blockchain
# 2. **Experiments** - Run MI, DP, Robustness, Latency tests
# 3. **Visualization** - Generate and display all 5 plots
#
# **Estimated Total Time**: 15-25 minutes
#
# ---

# %%
## 📁 1. Google Drive Sync & Project Setup
from google.colab import drive
import os

print("Mounting Google Drive...")
os.chdir('/content')
drive.mount('/content/drive', force_remount=True)

# Update this path to match your Google Drive structure
PROJECT_PATH = '/content/drive/Othercomputers/My laptop/bxp267'

if os.path.exists(PROJECT_PATH):
    try:
        # %cd "$PROJECT_PATH"
        print(f"✅ Project directory: {os.getcwd()}")

        # Clean old results for fresh run
        # !rm -f test/*.csv test/*.png
        print("🧹 Cleaned old results. Ready for fresh scientific run.")
    except Exception as e:
        print(f"❌ Error: {e}")
else:
    print(f"❌ Path not found: {PROJECT_PATH}")
    print("Please update PROJECT_PATH to match your Google Drive structure.")
# Out:
# Mounting Google Drive...
# Mounted at /content/drive
# /content/drive/Othercomputers/My laptop/bxp267
# ✅ Project directory: /content/drive/Othercomputers/My laptop/bxp267
# 🧹 Cleaned old results. Ready for fresh scientific run.

# %%
## 🛠️ 2. Environment Setup
print("Installing dependencies (this may take 2-3 minutes)...\n")

# Install Python dependencies
# !pip install -q "protobuf<6" "cryptography<44" "flwr[simulation]" opacus ucimlrepo web3 kagglehub imbalanced-learn

# Install Ganache (blockchain simulator)
# !npm install -g ganache --legacy-peer-deps 2>&1 | tail -1

print("\n" + "="*70)
print("🔍 Verifying Critical Imports...")
print("="*70 + "\n")

# Verify critical imports
try:
    import flwr
    print(f"✅ flwr version: {flwr.__version__}")
except ImportError as e:
    print(f"❌ flwr import failed: {e}")
    print("\n⚠️ IMPORTANT: You may need to restart the runtime.")
    print("   Go to: Runtime → Restart runtime")
    print("   Then re-run this cell.\n")

try:
    import torch
    print(f"✅ torch version: {torch.__version__}")
except ImportError as e:
    print(f"❌ torch import failed: {e}")

try:
    import opacus
    print(f"✅ opacus version: {opacus.__version__}")
except ImportError as e:
    print(f"❌ opacus import failed: {e}")

try:
    from web3 import Web3
    print(f"✅ web3 version: {Web3.__version__ if hasattr(Web3, '__version__') else 'installed'}")
except ImportError as e:
    print(f"❌ web3 import failed: {e}")

# Import standard libraries
import os, subprocess, time, json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

print("\n" + "="*70)
print("✅ Environment setup complete.")
print(f"📁 Current directory: {os.getcwd()}")
print("="*70)
# Out:
# Installing dependencies (this may take 2-3 minutes)...
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.4/254.4 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.5/587.5 kB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 48.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.7/531.7 kB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.3/340.3 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.8/175.8 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 66.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grain 0.2.15 requires protobuf>=5.28.3, but you have protobuf 4.25.8 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# ydf 0.14.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
#   run `npm fund` for details
#
# ======================================================================
# 🔍 Verifying Critical Imports...
# ======================================================================
#
# ✅ flwr version: 1.15.2
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ✅ torch version: 2.9.0+cpu
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ✅ opacus version: 1.5.4
# ✅ web3 version: installed
#
# ======================================================================
# ✅ Environment setup complete.
# 📁 Current directory: /content/drive/Othercomputers/My laptop/bxp267
# ======================================================================
# /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions
#   warnings.warn(  # deprecated in 14.0 - 2024-11-09

# %%
## 🚀 3. Blockchain Infrastructure
import socket, time, subprocess, os, json, urllib.request

RPC_PORT = "8545"

print(f"Cleaning up port {RPC_PORT}...")
# !lsof -ti:$RPC_PORT | xargs kill -9 > /dev/null 2>&1
time.sleep(2)

print(f"Starting Ganache on port {RPC_PORT}...")
subprocess.Popen(
    ["ganache", "--port", RPC_PORT, "--miner.blockGasLimit", "0xffffffffffff", "--wallet.defaultBalance", "100"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)

time.sleep(5)  # Wait for Ganache to start

print("Deploying smart contracts...")
# !python scripts/deploy_colab.py

print("\n✅ Blockchain infrastructure ready.")
# Out:
# Cleaning up port 8545...
# Starting Ganache on port 8545...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Deploying smart contracts...
# Connecting to local blockchain...
# ✅ Connected to Ganache on port 8545
# Deploying from: 0xf300815d99a6B8c530ade3cfa2bcB0742A177efD
# Deploying MedShareTask...
# [Success] MedShareTask deployed to: 0x5fDDF8B03fD7437623774dE74Ac0cEEeeE468be5
# Deploying CommitmentRegistry...
# [Success] CommitmentRegistry deployed to: 0xA7D9eB5C23ceFcff0ffedB3dFBEd35D265197D67
# Deploying Reputation...
# [Success] Reputation deployed to: 0x51AD2B8a6255f4a901ff2Dc89F0323a6eA9787a2
#
# [Success] Deployment summary saved to build/deploy_info.json
#
# ✅ Blockchain infrastructure ready.

# %%
## 🔍 Pre-Experiment System Check
import sys
import importlib

print("="*70)
print("🔍 PRE-EXPERIMENT SYSTEM CHECK")
print("="*70 + "\n")

# Critical modules check
critical_modules = ['flwr', 'torch', 'opacus', 'web3']
all_ok = True

for module_name in critical_modules:
    try:
        module = importlib.import_module(module_name)
        version = getattr(module, '__version__', 'unknown')
        print(f"✅ {module_name}: {version}")
    except ImportError:
        print(f"❌ {module_name}: NOT FOUND")
        all_ok = False

# Check file structure
print("\n📁 Checking Project Files:\n")

required_files = [
    'federated_survival.py',
    'test/plot_results.py',
    'scripts/deploy_colab.py',
    'medshare/client.py',
    'medshare/engine.py'
]

for file_path in required_files:
    if os.path.exists(file_path):
        print(f"✅ {file_path}")
    else:
        print(f"❌ {file_path} (missing)")
        all_ok = False

print("\n" + "="*70)
if all_ok:
    print("✅ ALL PRE-CHECKS PASSED - Ready to run experiments!")
else:
    print("❌ PRE-CHECK FAILED - Please fix issues above before proceeding.")
    print("\nCommon fixes:")
    print("  - For missing modules: Restart runtime and re-run setup cell")
    print("  - For missing files: Check Google Drive sync and PROJECT_PATH")
print("="*70)
# Out:
# ======================================================================
# 🔍 PRE-EXPERIMENT SYSTEM CHECK
# ======================================================================
#
# ✅ flwr: 1.15.2
# ✅ torch: 2.9.0+cpu
# ✅ opacus: 1.5.4
# ✅ web3: 7.14.1
#
# 📁 Checking Project Files:
#
# ✅ federated_survival.py
# ✅ test/plot_results.py
# ✅ scripts/deploy_colab.py
# ✅ medshare/client.py
# ✅ medshare/engine.py
#
# ======================================================================
# ✅ ALL PRE-CHECKS PASSED - Ready to run experiments!
# ======================================================================

# %%
## 🧪 4. Master Experiment Sweep (Complete Dataset)
# Runs all scientific experiments: MI Audit, DP Tradeoff, Robustness, Latency

DATASET = "support2_disease"  # Full survival analysis dataset

experiments = ["mi", "dp", "robustness", "latency"]

for exp in experiments:
    print(f"\n{'='*70}")
    print(f"🔬 RUNNING {exp.upper()} EXPERIMENT (Whole Dataset, 20 Rounds)")
    print(f"{'='*70}\n")

    # !python federated_survival.py \
        --experiment $exp \
        --dataset $DATASET \
        --rounds 20 \
        --epochs 5 \
        --enable_blockchain True

# Final system validation (includes gas cost tracking)
print(f"\n{'='*70}")
print(f"🔬 FINAL SYSTEM VALIDATION (Gas Cost Tracking)")
print(f"{'='*70}\n")

# !python federated_survival.py \
    --dataset $DATASET \
    --rounds 5 \
    --epochs 5 \
    --enable_blockchain True \
    --experiment none

print(f"\n{'='*70}")
print("✅ ALL SCIENTIFIC EXPERIMENTS COMPLETE")
print(f"{'='*70}")
# Out:
# ======================================================================
# 🔬 RUNNING MI EXPERIMENT (Whole Dataset, 20 Rounds)
# ======================================================================
#
# 2026-02-09 16:38:55.901215: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770655135.957933    2515 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770655135.971563    2515 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770655136.002863    2515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770655136.002961    2515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770655136.002975    2515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770655136.002998    2515 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions
#   warnings.warn(  # deprecated in 14.0 - 2024-11-09
# [Module] Loading medshare.strategy
# [Data] Encoded categorical target 'dzgroup' into 8 classes.
# [Experiment] Dataset: SUPPORT2-DiseaseGroup (9105 rows)
# [Experiment] Calibration: Batch=128, DP-Steps=[0.1, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5]
#
# [Audit] Running BASELINE (No Privacy) (20 rounds, 25 epochs)
# [Logging] Session state reset.
# [Data] Encoded categorical target 'dzgroup' into 8 classes.
# [INIT] Loaded 9105 records across 5 hospitals.
# [Blockchain] Connected to http://127.0.0.1:8545
# [INIT] Starting simulation for SUPPORT2-DiseaseGroup with 20 rounds...
# [Blockchain] Posting task with 0.05 ETH bounty...
# [Blockchain] Task 0 created with 0.05 ETH bounty. Tx: 444a582196...
# WARNING :
# Setting `min_available_clients` lower than `min_fit_clients` or
# `min_evaluate_clients` can cause the server to fail when there are too few clients
# connected to the server. `min_available_clients` must be set to a value larger
# than or equal to the values of `min_fit_clients` and `min_evaluate_clients`.
#
# INFO :      Starting Flower ServerApp, config: num_rounds=20, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 2 clients (out of 5)
# (pid=2960) 2026-02-09 16:40:08.680717: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2960) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=2960) E0000 00:00:1770655209.001895    2960 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2959) E0000 00:00:1770655209.111430    2959 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2959) W0000 00:00:1770655209.330773    2959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=2959) W0000 00:00:1770655209.330884    2959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=2959) W0000 00:00:1770655209.330891    2959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=2959) W0000 00:00:1770655209.330896    2959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (ClientAppActor pid=3077) /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions
# (ClientAppActor pid=3077)   warnings.warn(  # deprecated in 14.0 - 2024-11-09
# (pid=3051) 2026-02-09 16:40:11.099697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=3051) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 3x across cluster]
# (pid=3051) E0000 00:00:1770655211.336448    3051 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 3x across cluster]
# (pid=3051) E0000 00:00:1770655211.394694    3051 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 3x across cluster]
# (pid=3051) W0000 00:00:1770655211.851163    3051 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once. [repeated 12x across cluster]
# (ClientAppActor pid=3077) [Client] Initializing client 1 (Hospital_1)
# (ClientAppActor pid=3077) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=3051) [Blockchain] Connected to http://127.0.0.1:8545
# (ClientAppActor pid=3051) [Client] Initializing client 3 (Hospital_2)
# (ClientAppActor pid=3051) [Client 3] Starting fit on cpu...
# INFO :      aggregate_fit: received 2 results and 0 failures
# [Metrics] Aggregating 2 clients for Round 1
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=3077) [Client] Initializing client 0 (Hospital_5)
# (ClientAppActor pid=2959) /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions [repeated 2x across cluster]
# (ClientAppActor pid=2959)   warnings.warn(  # deprecated in 14.0 - 2024-11-09 [repeated 2x across cluster]
# (ClientAppActor pid=3077) [Blockchain] Connected to http://127.0.0.1:8545
# (ClientAppActor pid=2959) [Client] Initializing client 3 (Hospital_2) [repeated 3x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 1
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=3051) [Client] Initializing client 4 (Hospital_3) [repeated 6x across cluster]
# (ClientAppActor pid=3051) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=2959) [Blockchain] Connected to http://127.0.0.1:8545
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 2
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 2 (Hospital_4)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 2
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client 3] Starting fit on cpu...
# (ClientAppActor pid=2960) [Blockchain] Connected to http://127.0.0.1:8545
# (ClientAppActor pid=3077) [Client] Initializing client 4 (Hospital_3) [repeated 9x across cluster]
# (ClientAppActor pid=3077) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 3
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 3
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 4 (Hospital_3) [repeated 10x across cluster]
# (ClientAppActor pid=2959) [Client 4] Starting fit on cpu... [repeated 5x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 4
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 4 (Hospital_3) [repeated 2x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 4
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=3077) [Client 2] Starting fit on cpu...
# (ClientAppActor pid=2960) [Client] Initializing client 4 (Hospital_3) [repeated 8x across cluster]
# (ClientAppActor pid=2960) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 5
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 5
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 4 (Hospital_3) [repeated 10x across cluster]
# (ClientAppActor pid=2959) [Client 4] Starting fit on cpu... [repeated 5x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 6
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 1 (Hospital_1)
# (ClientAppActor pid=2960) [Client] Initializing client 3 (Hospital_2)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 6
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=3051) [Client] Initializing client 4 (Hospital_3) [repeated 8x across cluster]
# (ClientAppActor pid=3051) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 7
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 7
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=3077) [Client] Initializing client 2 (Hospital_4) [repeated 9x across cluster]
# (ClientAppActor pid=2959) [Client 0] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=3077) [Client] Initializing client 4 (Hospital_3)
# (ClientAppActor pid=3077) [Client 4] Starting fit on cpu...
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 8
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 0 (Hospital_5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 8
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2960) [Client 3] Starting fit on cpu...
# (ClientAppActor pid=2960) [Client] Initializing client 4 (Hospital_3) [repeated 9x across cluster]
# (ClientAppActor pid=2960) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 9
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 9
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 0 (Hospital_5) [repeated 6x across cluster]
# (ClientAppActor pid=2960) [Client 2] Starting fit on cpu...
# (ClientAppActor pid=3051) [Client] Initializing client 4 (Hospital_3) [repeated 4x across cluster]
# (ClientAppActor pid=3051) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 10
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 0 (Hospital_5)
# (ClientAppActor pid=2960) [Client] Initializing client 2 (Hospital_4)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 10
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2960) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=3051) [Client] Initializing client 4 (Hospital_3) [repeated 8x across cluster]
# (ClientAppActor pid=3051) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 11
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 11
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2960) [Client] Initializing client 4 (Hospital_3) [repeated 10x across cluster]
# (ClientAppActor pid=2960) [Client 4] Starting fit on cpu... [repeated 5x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 12
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 12
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=3051) [Client] Initializing client 3 (Hospital_2) [repeated 10x across cluster]
# (ClientAppActor pid=3051) [Client 3] Starting fit on cpu... [repeated 5x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 13
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 2 (Hospital_4)
# (ClientAppActor pid=2960) [Client] Initializing client 0 (Hospital_5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 13
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2960) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=2960) [Client] Initializing client 4 (Hospital_3) [repeated 8x across cluster]
# (ClientAppActor pid=2959) [Client 0] Starting fit on cpu... [repeated 3x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 14
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 0 (Hospital_5)
# (ClientAppActor pid=2960) [Client 4] Starting fit on cpu...
# (ClientAppActor pid=2960) [Client] Initializing client 1 (Hospital_1)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 14
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2960) [Client 3] Starting fit on cpu...
# (ClientAppActor pid=2960) [Client] Initializing client 4 (Hospital_3) [repeated 8x across cluster]
# (ClientAppActor pid=2960) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 15
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 15
# INFO :
# INFO :      [ROUND 16]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2960) [Client] Initializing client 4 (Hospital_3) [repeated 10x across cluster]
# (ClientAppActor pid=2960) [Client 4] Starting fit on cpu... [repeated 5x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 16
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 16
# INFO :
# INFO :      [ROUND 17]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 1 (Hospital_1) [repeated 6x across cluster]
# (ClientAppActor pid=2959) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=2960) [Client 3] Starting fit on cpu...
# (ClientAppActor pid=3051) [Client] Initializing client 4 (Hospital_3) [repeated 4x across cluster]
# (ClientAppActor pid=3051) [Client 4] Starting fit on cpu... [repeated 3x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 17
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 17
# INFO :
# INFO :      [ROUND 18]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=3077) [Client] Initializing client 0 (Hospital_5) [repeated 9x across cluster]
# (ClientAppActor pid=3077) [Client 0] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 18
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=3077) [Client] Initializing client 0 (Hospital_5) [repeated 2x across cluster]
# (ClientAppActor pid=3051) [Client 4] Starting fit on cpu...
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 18
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=3077) [Client] Initializing client 4 (Hospital_3) [repeated 9x across cluster]
# (ClientAppActor pid=3077) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 19
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2959) [Client] Initializing client 3 (Hospital_2)
# (ClientAppActor pid=2960) [Client] Initializing client 2 (Hospital_4)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 19
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=2960) [Client 2] Starting fit on cpu...
# (ClientAppActor pid=3077) [Client] Initializing client 4 (Hospital_3) [repeated 8x across cluster]
# (ClientAppActor pid=3077) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 20
# [Blockchain] Task 0 finalized. Bounty distributed.
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 20
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 360.05s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.4279012621310058
# INFO :      		round 2: 0.41053111496737205
# INFO :      		round 3: 0.4035944598731186
# INFO :      		round 4: 0.41268732122059254
# INFO :      		round 5: 0.4293462475674923
# INFO :      		round 6: 0.4114128747322503
# INFO :      		round 7: 0.4061982021795634
# INFO :      		round 8: 0.3829839541720699
# INFO :      		round 9: 0.40746959201442534
# INFO :      		round 10: 0.3944792864167466
# INFO :      		round 11: 0.4224339568008995
# INFO :      		round 12: 0.4124817477270462
# INFO :      		round 13: 0.4169051694377377
# INFO :      		round 14: 0.4325828242833794
# INFO :      		round 15: 0.43195536461842515
# INFO :      		round 16: 0.4762871921236848
# INFO :      		round 17: 0.47739387725776716
# INFO :      		round 18: 0.47239390298966666
# INFO :      		round 19: 0.4999282720276851
# INFO :      		round 20: 0.4896854177365291
# INFO :      	History (metrics, distributed, fit):
# INFO :      	{'accuracy': [(1, 0.8244609860758385),
# INFO :      	              (2, 0.6709718952254142),
# INFO :      	              (3, 0.6973149973069717),
# INFO :      	              (4, 0.6973065863752402),
# INFO :      	              (5, 0.7082891996455958),
# INFO :      	              (6, 0.7093945882419256),
# INFO :      	              (7, 0.7137732867748217),
# INFO :      	              (8, 0.7280391596158268),
# INFO :      	              (9, 0.7258430462565811),
# INFO :      	              (10, 0.7258518745613255),
# INFO :      	              (11, 0.7214631714712206),
# INFO :      	              (12, 0.7231028257336923),
# INFO :      	              (13, 0.7291344154297515),
# INFO :      	              (14, 0.7263907411612086),
# INFO :      	              (15, 0.7269440961396958),
# INFO :      	              (16, 0.7274894866238425),
# INFO :      	              (17, 0.7307799357812316),
# INFO :      	              (18, 0.7241962945158024),
# INFO :      	              (19, 0.728587648448126),
# INFO :      	              (20, 0.7307794983196044)],
# INFO :      	 'auc': [(1, 0.9787032663585409),
# INFO :      	         (2, 0.9275902959802558),
# INFO :      	         (3, 0.9299269999720227),
# INFO :      	         (4, 0.9311379496569014),
# INFO :      	         (5, 0.9320875853992612),
# INFO :      	         (6, 0.9287387201685882),
# INFO :      	         (7, 0.9286254283800843),
# INFO :      	         (8, 0.9280393671302374),
# INFO :      	         (9, 0.9283473064086547),
# INFO :      	         (10, 0.9304952306254775),
# INFO :      	         (11, 0.9319371571617034),
# INFO :      	         (12, 0.9307297867102753),
# INFO :      	         (13, 0.9325779512156372),
# INFO :      	         (14, 0.9329770143941423),
# INFO :      	         (15, 0.9347100455493897),
# INFO :      	         (16, 0.9360665414190121),
# INFO :      	         (17, 0.9374246936101256),
# INFO :      	         (18, 0.9373328210068108),
# INFO :      	         (19, 0.9369393209688714),
# INFO :      	         (20, 0.9396479274782111)],
# INFO :      	 'mi_score': [(1, 0.022460810929153197),
# INFO :      	              (2, 0.1949989918935091),
# INFO :      	              (3, 0.19598354704897447),
# INFO :      	              (4, 0.20642865119685538),
# INFO :      	              (5, 0.21316095141180602),
# INFO :      	              (6, 0.22537607915714064),
# INFO :      	              (7, 0.2322580233048268),
# INFO :      	              (8, 0.23502043939543382),
# INFO :      	              (9, 0.24545604739900795),
# INFO :      	              (10, 0.25203881480972645),
# INFO :      	              (11, 0.25354369477431626),
# INFO :      	              (12, 0.2644006073890761),
# INFO :      	              (13, 0.261115515907793),
# INFO :      	              (14, 0.26578173892667933),
# INFO :      	              (15, 0.2656403586804086),
# INFO :      	              (16, 0.26454566855330663),
# INFO :      	              (17, 0.26729751546842506),
# INFO :      	              (18, 0.2705853588761229),
# INFO :      	              (19, 0.2615249579786799),
# INFO :      	              (20, 0.2661993536441418)]}
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.8102029621503017),
# INFO :      	              (2, 0.8288535381239714),
# INFO :      	              (3, 0.8348875479978058),
# INFO :      	              (4, 0.8261108063631377),
# INFO :      	              (5, 0.8354360943499726),
# INFO :      	              (6, 0.834339001645639),
# INFO :      	              (7, 0.8398244651673067),
# INFO :      	              (8, 0.8546352166758091),
# INFO :      	              (9, 0.8491497531541415),
# INFO :      	              (10, 0.8557323093801427),
# INFO :      	              (11, 0.8535381239714755),
# INFO :      	              (12, 0.8623148656061437),
# INFO :      	              (13, 0.857377948436643),
# INFO :      	              (14, 0.8579264947888097),
# INFO :      	              (15, 0.8645090510148108),
# INFO :      	              (16, 0.8518924849149753),
# INFO :      	              (17, 0.8546352166758091),
# INFO :      	              (18, 0.8546352166758091),
# INFO :      	              (19, 0.8529895776193088),
# INFO :      	              (20, 0.857377948436643)],
# INFO :      	 'auc': [(1, 0.9775957841692777),
# INFO :      	         (2, 0.9813923378935204),
# INFO :      	         (3, 0.9828556012962892),
# INFO :      	         (4, 0.9835484545202294),
# INFO :      	         (5, 0.9840449937815144),
# INFO :      	         (6, 0.9845099095295746),
# INFO :      	         (7, 0.984833871343565),
# INFO :      	         (8, 0.985476158092192),
# INFO :      	         (9, 0.9847589883074592),
# INFO :      	         (10, 0.9848160283175439),
# INFO :      	         (11, 0.9842811470515836),
# INFO :      	         (12, 0.9844563539007597),
# INFO :      	         (13, 0.9843336709725935),
# INFO :      	         (14, 0.9841541709741491),
# INFO :      	         (15, 0.9838347212820432),
# INFO :      	         (16, 0.9830042688810651),
# INFO :      	         (17, 0.9827551571115802),
# INFO :      	         (18, 0.9830825577911213),
# INFO :      	         (19, 0.9828101161019173),
# INFO :      	         (20, 0.9829535913370268)],
# INFO :      	 'mi_score': [(1, 0.022460810929153197),
# INFO :      	              (2, 0.1949989918935091),
# INFO :      	              (3, 0.19598354704897447),
# INFO :      	              (4, 0.20642865119685538),
# INFO :      	              (5, 0.21316095141180602),
# INFO :      	              (6, 0.22537607915714064),
# INFO :      	              (7, 0.2322580233048268),
# INFO :      	              (8, 0.23502043939543382),
# INFO :      	              (9, 0.24545604739900795),
# INFO :      	              (10, 0.25203881480972645),
# INFO :      	              (11, 0.25354369477431626),
# INFO :      	              (12, 0.2644006073890761),
# INFO :      	              (13, 0.261115515907793),
# INFO :      	              (14, 0.26578173892667933),
# INFO :      	              (15, 0.2656403586804086),
# INFO :      	              (16, 0.26454566855330663),
# INFO :      	              (17, 0.26729751546842506),
# INFO :      	              (18, 0.2705853588761229),
# INFO :      	              (19, 0.2615249579786799),
# INFO :      	              (20, 0.2661993536441418)]}
# INFO :
# (ClientAppActor pid=3077) [Client] Initializing client 0 (Hospital_5) [repeated 5x across cluster]
# (ClientAppActor pid=2960) /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions
# (ClientAppActor pid=2960)   warnings.warn(  # deprecated in 14.0 - 2024-11-09
# [Results] Extracted from history: Acc=0.8574, AUC=0.9830, Epsilon=0.00
# [Baseline] Calculating Local Baselines for each hospital...
#
# [Audit] Running MI Audit with sigma=0.1 (20 rounds, 25 epochs)
# [Logging] Session state reset.
# [Data] Encoded categorical target 'dzgroup' into 8 classes.
# [INIT] Loaded 9105 records across 5 hospitals.
# [INIT] Starting simulation for SUPPORT2-DiseaseGroup with 20 rounds...
# [Blockchain] Posting task with 0.05 ETH bounty...
# [Blockchain] Task 1 created with 0.05 ETH bounty. Tx: ffd9f3fd3a...
# WARNING :
# Setting `min_available_clients` lower than `min_fit_clients` or
# `min_evaluate_clients` can cause the server to fail when there are too few clients
# connected to the server. `min_available_clients` must be set to a value larger
# than or equal to the values of `min_fit_clients` and `min_evaluate_clients`.
#
# INFO :      Starting Flower ServerApp, config: num_rounds=20, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (pid=5001) 2026-02-09 16:46:15.686472: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=5001) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=5001) E0000 00:00:1770655575.814430    5001 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=5001) E0000 00:00:1770655575.828794    5001 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=5001) W0000 00:00:1770655575.861482    5001 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=5001) W0000 00:00:1770655575.861591    5001 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=5001) W0000 00:00:1770655575.861596    5001 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=5001) W0000 00:00:1770655575.861600    5001 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (ClientAppActor pid=5001) /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions
# (ClientAppActor pid=5001)   warnings.warn(  # deprecated in 14.0 - 2024-11-09
# (pid=5114) 2026-02-09 16:46:17.335261: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered [repeated 3x across cluster]
# (pid=5114) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR [repeated 3x across cluster]
# (pid=5114) E0000 00:00:1770655577.408334    5114 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered [repeated 3x across cluster]
# (pid=5114) E0000 00:00:1770655577.433438    5114 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered [repeated 3x across cluster]
# (pid=5114) W0000 00:00:1770655577.502381    5114 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once. [repeated 12x across cluster]
# (ClientAppActor pid=5001) [Client] Initializing client 2 (Hospital_4)
# (ClientAppActor pid=5001) [Client 2] Starting fit on cpu...
# (ClientAppActor pid=5001) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5001)   warnings.warn(
# (ClientAppActor pid=5001) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5001)   loss.backward()
# (ClientAppActor pid=5085) /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions [repeated 3x across cluster]
# (ClientAppActor pid=5085)   warnings.warn(  # deprecated in 14.0 - 2024-11-09 [repeated 3x across cluster]
# (ClientAppActor pid=5085) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 3x across cluster]
# (ClientAppActor pid=5085)   warnings.warn( [repeated 3x across cluster]
# (ClientAppActor pid=5000) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
# (ClientAppActor pid=5085) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 3x across cluster]
# (ClientAppActor pid=5085)   loss.backward() [repeated 3x across cluster]
# (ClientAppActor pid=5000)   warnings.warn(
# (ClientAppActor pid=5000) [Blockchain] Connected to http://127.0.0.1:8545
# (ClientAppActor pid=5085) [Client] Initializing client 1 (Hospital_3) [repeated 3x across cluster]
# (ClientAppActor pid=5085) [Client 1] Starting fit on cpu... [repeated 3x across cluster]
# (ClientAppActor pid=5001)   warnings.warn(
# (ClientAppActor pid=5000) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5114) [Blockchain] Connected to http://127.0.0.1:8545 [repeated 3x across cluster]
# (ClientAppActor pid=5000) [Client] Initializing client 4 (Hospital_1)
# (ClientAppActor pid=5000) [Client 4] Starting fit on cpu...
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound. [repeated 3x across cluster]
# (ClientAppActor pid=5000) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5000)   loss.backward()
# (ClientAppActor pid=5114)   warnings.warn( [repeated 3x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 1
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=5001) [Client] Initializing client 2 (Hospital_4)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 1
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=5114) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5114) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5114)   loss.backward()
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound. [repeated 2x across cluster]
# (ClientAppActor pid=5114)   warnings.warn( [repeated 6x across cluster]
# (ClientAppActor pid=5000) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 3x across cluster]
# (ClientAppActor pid=5085) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 3x across cluster]
# (ClientAppActor pid=5085)   loss.backward() [repeated 3x across cluster]
# (ClientAppActor pid=5114) [Client] Initializing client 4 (Hospital_1) [repeated 9x across cluster]
# (ClientAppActor pid=5114) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=5000) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound. [repeated 3x across cluster]
# (ClientAppActor pid=5000)   warnings.warn( [repeated 4x across cluster]
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5114) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5114)   loss.backward()
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 2
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=5000) [Client] Initializing client 1 (Hospital_3)
# (ClientAppActor pid=5001) [Client] Initializing client 2 (Hospital_4)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 2
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=5000) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5000) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5000)   loss.backward()
# (ClientAppActor pid=5000) [Client 3] Starting fit on cpu...
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound. [repeated 2x across cluster]
# (ClientAppActor pid=5114)   warnings.warn( [repeated 6x across cluster]
# (ClientAppActor pid=5085) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 3x across cluster]
# (ClientAppActor pid=5085) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 3x across cluster]
# (ClientAppActor pid=5085)   loss.backward() [repeated 3x across cluster]
# (ClientAppActor pid=5114) [Client] Initializing client 4 (Hospital_1) [repeated 8x across cluster]
# (ClientAppActor pid=5114) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=5085) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound. [repeated 3x across cluster]
# (ClientAppActor pid=5085)   warnings.warn( [repeated 4x across cluster]
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5114) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5114)   loss.backward()
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 3
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=5001) [Client] Initializing client 2 (Hospital_4)
# (ClientAppActor pid=5114) [Client] Initializing client 0 (Hospital_5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 3
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=5000) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5000) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=5000) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5000)   loss.backward()
# (ClientAppActor pid=5001) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound. [repeated 2x across cluster]
# (ClientAppActor pid=5001)   warnings.warn( [repeated 6x across cluster]
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 3x across cluster]
# (ClientAppActor pid=5114) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 3x across cluster]
# (ClientAppActor pid=5114)   loss.backward() [repeated 3x across cluster]
# (ClientAppActor pid=5001) [Client] Initializing client 4 (Hospital_1) [repeated 8x across cluster]
# (ClientAppActor pid=5001) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=5114) /usr/local/lib/python3.12/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound. [repeated 3x across cluster]
# (ClientAppActor pid=5114)   warnings.warn( [repeated 4x across cluster]
# (ClientAppActor pid=5001) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=5001) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=5001)   loss.backward()
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 4
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=5000) [Client] Initializing client 3 (Hospital_2)
# ...
# (ClientAppActor pid=25646)   warnings.warn(  # deprecated in 14.0 - 2024-11-09 [repeated 2x across cluster]
# (ClientAppActor pid=25758) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25758)   warnings.warn(
# (ClientAppActor pid=25758) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25758)   loss.backward()
# (ClientAppActor pid=25646) [Client] Initializing client 3 (Hospital_4) [repeated 3x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 1
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25732) [Client 3] Starting fit on cpu...
# (ClientAppActor pid=25732) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25732)   warnings.warn(
# (ClientAppActor pid=25732) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25732)   loss.backward()
# (ClientAppActor pid=25647) /usr/local/lib/python3.12/dist-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions
# (ClientAppActor pid=25647)   warnings.warn(  # deprecated in 14.0 - 2024-11-09
# (ClientAppActor pid=25647) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 3x across cluster]
# (ClientAppActor pid=25647)   warnings.warn( [repeated 3x across cluster]
# (ClientAppActor pid=25647) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 2x across cluster]
# (ClientAppActor pid=25647)   loss.backward() [repeated 2x across cluster]
# (ClientAppActor pid=25732) [Client] Initializing client 4 (Hospital_2) [repeated 6x across cluster]
# (ClientAppActor pid=25732) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=25732) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25732)   warnings.warn(
# (ClientAppActor pid=25646) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25646)   loss.backward()
# (ClientAppActor pid=25732) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25732)   loss.backward()
# (ClientAppActor pid=25646) [Blockchain] Connected to http://127.0.0.1:8545
# (ClientAppActor pid=25647) [Blockchain] Connected to http://127.0.0.1:8545
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 2
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25646) [Client] Initializing client 2 (Hospital_5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 2
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25646) [Client 2] Starting fit on cpu...
# (ClientAppActor pid=25646) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25646)   warnings.warn(
# (ClientAppActor pid=25646) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25646)   loss.backward()
# (ClientAppActor pid=25646) [Client] Initializing client 4 (Hospital_2) [repeated 9x across cluster]
# (ClientAppActor pid=25732) [Client 1] Starting fit on cpu... [repeated 3x across cluster]
# (ClientAppActor pid=25646) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 4x across cluster]
# (ClientAppActor pid=25646)   warnings.warn( [repeated 4x across cluster]
# (ClientAppActor pid=25647) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 3x across cluster]
# (ClientAppActor pid=25647)   loss.backward() [repeated 3x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 3
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25647) [Client] Initializing client 1 (Hospital_3)
# (ClientAppActor pid=25646) [Client 4] Starting fit on cpu...
# (ClientAppActor pid=25758) [Client] Initializing client 2 (Hospital_5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 3
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25732) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=25732) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25732)   warnings.warn(
# (ClientAppActor pid=25646) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25646)   loss.backward()
# (ClientAppActor pid=25758) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25758)   warnings.warn(
# (ClientAppActor pid=25732) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25732)   loss.backward()
# (ClientAppActor pid=25646) [Client] Initializing client 4 (Hospital_2) [repeated 8x across cluster]
# (ClientAppActor pid=25646) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=25646) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 3x across cluster]
# (ClientAppActor pid=25646)   warnings.warn( [repeated 3x across cluster]
# (ClientAppActor pid=25647) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 3x across cluster]
# (ClientAppActor pid=25647)   loss.backward() [repeated 3x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 4
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25646) [Client] Initializing client 0 (Hospital_1)
# (ClientAppActor pid=25647) [Client] Initializing client 3 (Hospital_4)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 4
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25647) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25647)   warnings.warn(
# (ClientAppActor pid=25646) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25646)   loss.backward()
# (ClientAppActor pid=25647) [Client 1] Starting fit on cpu...
# (ClientAppActor pid=25732) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25732)   warnings.warn(
# (ClientAppActor pid=25758) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25758)   loss.backward()
# (ClientAppActor pid=25732) [Client] Initializing client 4 (Hospital_2) [repeated 8x across cluster]
# (ClientAppActor pid=25732) [Client 4] Starting fit on cpu... [repeated 4x across cluster]
# (ClientAppActor pid=25732) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on. [repeated 3x across cluster]
# (ClientAppActor pid=25732)   warnings.warn( [repeated 3x across cluster]
# (ClientAppActor pid=25732) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details. [repeated 3x across cluster]
# (ClientAppActor pid=25732)   loss.backward() [repeated 3x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 5
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25732) [Client] Initializing client 0 (Hospital_1)
# (ClientAppActor pid=25646) [Client] Initializing client 2 (Hospital_5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# [Metrics] Aggregating 5 clients for Round 5
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=25646) [Client 3] Starting fit on cpu...
# (ClientAppActor pid=25646) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25646)   warnings.warn(
# (ClientAppActor pid=25732) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25732)   loss.backward()
# (ClientAppActor pid=25647) /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
# (ClientAppActor pid=25647)   warnings.warn(
# (ClientAppActor pid=25732) /content/drive/Othercomputers/My laptop/bxp267/medshare/engine.py:47: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# (ClientAppActor pid=25732)   loss.backward()

# %%
## 🔍 4. High-Intensity Privacy Audit (Leakage Baseline)
print("="*70)
print("🚀 RUNNING HIGH-INTENSITY PRIVACY AUDIT")
print("Objective: Force overfitting to observe baseline leakage (No Privacy)")
print("="*70 + "\n")

# Run with 10 rounds and 10 local epochs to simulate high-intensity attack
# !python federated_survival.py --dataset support2 --rounds 10 --epochs 10 --experiment mi

print("\n✅ Audit Complete. Check 'exp_mi_results.csv' for detailed leakage vs noise analysis.")

# %%
## ✅ 5. Verify Generated Data Files
import os

csv_files = [
    "test/exp_dp_results.csv",
    "test/exp_mi_results.csv",
    "test/exp_robustness_results.csv",
    "test/exp_gas_log.csv",
    "test/exp_latency_log.csv"
]

print("\n📊 Data Files Status:\n" + "="*50)
found = 0
for f in csv_files:
    if os.path.exists(f):
        size = os.path.getsize(f)
        print(f"✅ {f} ({size:,} bytes)")
        found += 1
    else:
        print(f"❌ {f} (missing)")

print(f"\n📈 Found {found}/5 data files")

if found == 5:
    print("\n🎉 All data files generated successfully!")
else:
    print(f"\n⚠️ Warning: {5-found} data file(s) missing. Some plots may not generate.")

# %%
## 📊 6. Generate All Plots
print("Generating scientific visualization plots...\n")

if os.path.exists("test/plot_results.py"):
    # !python test/plot_results.py
else:
    print("❌ plot_results.py not found!")

# Verify generated plots
plot_files = [
    "test/fig_mi.png",
    "test/fig_dp_tradeoff.png",
    "test/fig_robustness.png",
    "test/fig_gas_costs.png",
    "test/fig_latency.png"
]

print("\n📊 Generated Plots:\n" + "="*50)
generated = 0
for plot in plot_files:
    if os.path.exists(plot):
        size = os.path.getsize(plot)
        print(f"✅ {plot} ({size:,} bytes)")
        generated += 1
    else:
        print(f"❌ {plot} (not generated)")

print(f"\n📈 Generated {generated}/5 plots")

# %%
## 🖼️ 7. Display All Scientific Plots
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

plots = [
    "test/fig_mi.png",
    "test/fig_dp_tradeoff.png",
    "test/fig_robustness.png",
    "test/fig_gas_costs.png",
    "test/fig_latency.png"
]

plot_titles = [
    "MI Leakage: Privacy Audit",
    "DP Tradeoff: Privacy vs Accuracy",
    "Robustness: Byzantine Attack Mitigation",
    "Gas Costs: Blockchain Transaction Analysis",
    "Latency: Round-to-Round Communication"
]

existing_plots = [(p, t) for p, t in zip(plots, plot_titles) if os.path.exists(p)]

if existing_plots:
    cols = 2
    rows = (len(existing_plots) + 1) // 2
    plt.figure(figsize=(22, 9 * rows))

    for i, (path, title) in enumerate(existing_plots):
        plt.subplot(rows, cols, i+1)
        img = mpimg.imread(path)
        plt.imshow(img)
        plt.axis('off')
        plt.title(title, fontsize=18, fontweight='bold', pad=15, color='#2E86AB')

    plt.tight_layout(pad=3.0)
    plt.show()

    print(f"\n🎉 Successfully displayed {len(existing_plots)}/5 plots!")
else:
    print("❌ No plots found!")
    print("\nPlease run the experiment sweep first (Cell 4).")

# %%
## 📋 8. Execution Summary Report
import os
import json

print("="*70)
print("📊 MEDSHARE EXECUTION SUMMARY")
print("="*70)

# Check data files
csv_files = [
    "test/exp_dp_results.csv",
    "test/exp_mi_results.csv",
    "test/exp_robustness_results.csv",
    "test/exp_gas_log.csv",
    "test/exp_latency_log.csv"
]

csv_count = sum(1 for f in csv_files if os.path.exists(f))

# Check plots
plot_files = [
    "test/fig_mi.png",
    "test/fig_dp_tradeoff.png",
    "test/fig_robustness.png",
    "test/fig_gas_costs.png",
    "test/fig_latency.png"
]

plot_count = sum(1 for f in plot_files if os.path.exists(f))

print(f"\n📁 Data Files: {csv_count}/5 generated")
print(f"📊 Plots: {plot_count}/5 generated")

# Check for comparison stats
if os.path.exists("comparison_stats.json"):
    with open("comparison_stats.json", "r") as f:
        stats = json.load(f)
    print(f"\n🎯 Final Global Accuracy: {stats.get('global_accuracy', 'N/A')}")
    print(f"🔐 Privacy Budget (ε): {stats.get('epsilon', 'N/A')}")
    print(f"⛓️ Blockchain Enabled: {stats.get('blockchain_enabled', 'N/A')}")

print("\n" + "="*70)

if csv_count == 5 and plot_count == 5:
    print("✅ FULL EXECUTION COMPLETE - ALL TESTS PASSED")
else:
    print(f"⚠️ PARTIAL EXECUTION - {5-csv_count} data files and {5-plot_count} plots missing")

print("="*70)
